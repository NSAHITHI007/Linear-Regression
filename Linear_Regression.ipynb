# %%
## N.sahithi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv("/content/customers.csv")

# %%
dataset.head(15)
# Out:
#     CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 8            9    Male   64                  19                       3
# 9           10  Female   30                  19                      72
# 10          11    Male   67                  19                      14
# 11          12  Female   35                  19                      99
# ...

# %%
dataset.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
dataset.shape
# Out:
# (200, 5)

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
dataset.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
sns.pairplot(dataset)

# %%
corr = dataset.corr()
sns.heatmap(corr, annot=True)

# %%
x= dataset.drop(['CustomerID', 'Age', 'Spending Score (1-100)','Genre'],axis=True)
y= dataset['Spending Score (1-100)']

# %%
x
# Out:
#      Annual Income (k$)
# 0                    15
# 1                    15
# 2                    16
# 3                    16
# 4                    17
# ..                  ...
# 195                 120
# 196                 126
# 197                 126
# 198                 137
# 199                 137
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      39
# 1      81
# 2       6
# 3      77
# 4      40
#        ..
# 195    79
# 196    28
# 197    74
# 198    18
# 199    83
# Name: Spending Score (1-100), Length: 200, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=model1.predict(x)

# %%
sns.lmplot(x= 'Annual Income (k$)',y= 'Spending Score (1-100)',data=dataset,aspect=2,height=7)

# %%
model1.predict([[130]])
# Out:
# array([50.87610244])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y,y_pred)
# Out:
# 9.806640037357539e-05
